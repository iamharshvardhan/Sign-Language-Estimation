# %%
import numpy as np
import cv2
import tensorflow as tf
import os
import time
import sklearn
import mediapipe as mp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
      
    # Make detection
    result = model.process(image)
    
    # Recolour back to BGR
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, result

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, result.face_landmarks, mp_holistic.FACEMESH_CONTOURS)
    mp_drawing.draw_landmarks(image, result.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image, result.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, result.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)

        image, result = mediapipe_detection(frame, holistic)
        # print(result)

        draw_styled_landmarks(image, result)
        
        cv2.imshow('OpenCV Feed', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_styled_landmarks(frame, result)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in result.pose_landmarks.landmark]).flatten() if result.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in result.face_landmarks.landmark]).flatten() if result.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in result.left_hand_landmarks.landmark]).flatten() if result.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in result.right_hand_landmarks.landmark]).flatten() if result.right_hand_landmarks else np.zeros(21*3)

# %%
pose[:5], face[:5], lh[:5], rh[:5]
# Out:
# (array([ 0.35414407,  0.5123226 , -0.70146739,  0.9999916 ,  0.37360531]),
#  array([ 0.34265202,  0.57236141, -0.02236279,  0.33674788,  0.53854036]),
#  array([7.57289827e-01, 4.47469473e-01, 3.19962311e-07, 7.01320469e-01,
#         4.36017513e-01]),
#  array([0., 0., 0., 0., 0.]))

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array(['hello', 'thank_you', 'i_love_you'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thank_you': 1, 'i_love_you': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test , y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 6s 72ms/step - loss: 2.0434 - categorical_accuracy: 0.3333
# Epoch 2/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.5547 - categorical_accuracy: 0.4028
# Epoch 3/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.3558 - categorical_accuracy: 0.2222
# Epoch 4/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 4.5528 - categorical_accuracy: 0.2917
# Epoch 5/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 4.6425 - categorical_accuracy: 0.3889
# Epoch 6/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 14.6024 - categorical_accuracy: 0.2500
# Epoch 7/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 19.8964 - categorical_accuracy: 0.2778
# Epoch 8/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 10.4395 - categorical_accuracy: 0.3472
# Epoch 9/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 4.7965 - categorical_accuracy: 0.3611
# Epoch 10/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 3.6558 - categorical_accuracy: 0.4444
# Epoch 11/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 4.0590 - categorical_accuracy: 0.3889
# Epoch 12/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 4.6233 - categorical_accuracy: 0.3472
# Epoch 13/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 5.7793 - categorical_accuracy: 0.3611
# Epoch 14/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 4.1202 - categorical_accuracy: 0.3611
# Epoch 15/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 14.0785 - categorical_accuracy: 0.3611
# Epoch 16/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 13.1805 - categorical_accuracy: 0.4028
# Epoch 17/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 9.0510 - categorical_accuracy: 0.3750
# Epoch 18/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.5438 - categorical_accuracy: 0.3333
# Epoch 19/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 9.2107 - categorical_accuracy: 0.2639
# Epoch 20/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 7.4254 - categorical_accuracy: 0.3194
# Epoch 21/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 5.0580 - categorical_accuracy: 0.3889
# Epoch 22/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 6.7147 - categorical_accuracy: 0.3194
# Epoch 23/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.8110 - categorical_accuracy: 0.4028
# Epoch 24/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.5030 - categorical_accuracy: 0.2639
# Epoch 25/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.8063 - categorical_accuracy: 0.4028
# Epoch 26/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.6844 - categorical_accuracy: 0.3750
# Epoch 27/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.3670 - categorical_accuracy: 0.3611
# Epoch 28/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.1945 - categorical_accuracy: 0.4167
# Epoch 29/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 1.9151 - categorical_accuracy: 0.2917
# Epoch 30/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1208 - categorical_accuracy: 0.2639
# Epoch 31/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1260 - categorical_accuracy: 0.3333
# Epoch 32/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1026 - categorical_accuracy: 0.4722
# Epoch 33/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.1464 - categorical_accuracy: 0.3750
# Epoch 34/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0777 - categorical_accuracy: 0.4306
# Epoch 35/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0511 - categorical_accuracy: 0.5000
# Epoch 36/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0788 - categorical_accuracy: 0.3611
# Epoch 37/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0457 - categorical_accuracy: 0.4167
# Epoch 38/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0272 - categorical_accuracy: 0.4861
# Epoch 39/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0624 - categorical_accuracy: 0.5278
# Epoch 40/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.1598 - categorical_accuracy: 0.4722
# Epoch 41/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.1804 - categorical_accuracy: 0.3750
# Epoch 42/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1422 - categorical_accuracy: 0.3611
# Epoch 43/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.1113 - categorical_accuracy: 0.3750
# Epoch 44/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.1111 - categorical_accuracy: 0.3750
# Epoch 45/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0902 - categorical_accuracy: 0.3889
# Epoch 46/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0985 - categorical_accuracy: 0.3611
# Epoch 47/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.1129 - categorical_accuracy: 0.3472
# Epoch 48/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0920 - categorical_accuracy: 0.4167
# Epoch 49/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1006 - categorical_accuracy: 0.3750
# Epoch 50/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1046 - categorical_accuracy: 0.3750
# Epoch 51/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 1.1032 - categorical_accuracy: 0.3750
# Epoch 52/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0987 - categorical_accuracy: 0.3056
# Epoch 53/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1063 - categorical_accuracy: 0.3194
# Epoch 54/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0943 - categorical_accuracy: 0.3611
# Epoch 55/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0925 - categorical_accuracy: 0.3472
# Epoch 56/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 1.0823 - categorical_accuracy: 0.3750
# Epoch 57/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0945 - categorical_accuracy: 0.3611
# Epoch 58/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.1069 - categorical_accuracy: 0.2778
# Epoch 59/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0847 - categorical_accuracy: 0.3472
# Epoch 60/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.1019 - categorical_accuracy: 0.3889
# Epoch 61/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.1210 - categorical_accuracy: 0.3611
# Epoch 62/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1256 - categorical_accuracy: 0.3611
# Epoch 63/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0904 - categorical_accuracy: 0.3611
# Epoch 64/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0866 - categorical_accuracy: 0.3472
# Epoch 65/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0847 - categorical_accuracy: 0.3333
# Epoch 66/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0779 - categorical_accuracy: 0.4167
# Epoch 67/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0826 - categorical_accuracy: 0.3889
# Epoch 68/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0807 - categorical_accuracy: 0.3750
# Epoch 69/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0890 - categorical_accuracy: 0.3889
# Epoch 70/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0871 - categorical_accuracy: 0.3472
# Epoch 71/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0861 - categorical_accuracy: 0.3750
# Epoch 72/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0699 - categorical_accuracy: 0.4583
# Epoch 73/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0742 - categorical_accuracy: 0.3750
# Epoch 74/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0730 - categorical_accuracy: 0.3889
# Epoch 75/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0722 - categorical_accuracy: 0.3750
# Epoch 76/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0858 - categorical_accuracy: 0.3750
# Epoch 77/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0559 - categorical_accuracy: 0.4861
# Epoch 78/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0938 - categorical_accuracy: 0.3889
# Epoch 79/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0772 - categorical_accuracy: 0.3889
# Epoch 80/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.1077 - categorical_accuracy: 0.4028
# Epoch 81/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0565 - categorical_accuracy: 0.4306
# Epoch 82/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0968 - categorical_accuracy: 0.3889
# Epoch 83/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0749 - categorical_accuracy: 0.3750
# Epoch 84/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0926 - categorical_accuracy: 0.4028
# Epoch 85/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0754 - categorical_accuracy: 0.3750
# Epoch 86/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0670 - categorical_accuracy: 0.4028
# Epoch 87/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 1.0840 - categorical_accuracy: 0.3889
# Epoch 88/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0549 - categorical_accuracy: 0.3889
# Epoch 89/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1146 - categorical_accuracy: 0.3750
# Epoch 90/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0852 - categorical_accuracy: 0.3889
# Epoch 91/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0576 - categorical_accuracy: 0.3889
# Epoch 92/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0801 - categorical_accuracy: 0.4306
# Epoch 93/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0312 - categorical_accuracy: 0.4306
# Epoch 94/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0430 - categorical_accuracy: 0.4167
# Epoch 95/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0831 - categorical_accuracy: 0.4167
# Epoch 96/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0946 - categorical_accuracy: 0.4028
# Epoch 97/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0450 - categorical_accuracy: 0.4028
# Epoch 98/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0480 - categorical_accuracy: 0.3611
# Epoch 99/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0794 - categorical_accuracy: 0.3056
# Epoch 100/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0719 - categorical_accuracy: 0.3889
# Epoch 101/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0880 - categorical_accuracy: 0.4028
# Epoch 102/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0795 - categorical_accuracy: 0.3889
# Epoch 103/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0675 - categorical_accuracy: 0.4861
# Epoch 104/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 1.1219 - categorical_accuracy: 0.3056
# Epoch 105/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0930 - categorical_accuracy: 0.3472
# Epoch 106/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0685 - categorical_accuracy: 0.3889
# Epoch 107/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1096 - categorical_accuracy: 0.3333
# Epoch 108/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1043 - categorical_accuracy: 0.3750
# Epoch 109/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0457 - categorical_accuracy: 0.4583
# Epoch 110/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0868 - categorical_accuracy: 0.2778
# Epoch 111/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0586 - categorical_accuracy: 0.4306
# Epoch 112/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.0500 - categorical_accuracy: 0.4444
# Epoch 113/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0309 - categorical_accuracy: 0.4722
# Epoch 114/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0885 - categorical_accuracy: 0.3194
# Epoch 115/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0429 - categorical_accuracy: 0.4167
# Epoch 116/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0496 - categorical_accuracy: 0.4583
# Epoch 117/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0334 - categorical_accuracy: 0.5556
# Epoch 118/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0585 - categorical_accuracy: 0.4306
# Epoch 119/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0408 - categorical_accuracy: 0.4444
# Epoch 120/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0559 - categorical_accuracy: 0.4028
# Epoch 121/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0593 - categorical_accuracy: 0.4861
# Epoch 122/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0128 - categorical_accuracy: 0.5139
# Epoch 123/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0025 - categorical_accuracy: 0.5139
# Epoch 124/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0213 - categorical_accuracy: 0.4583
# Epoch 125/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0213 - categorical_accuracy: 0.4028
# Epoch 126/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0196 - categorical_accuracy: 0.5694
# Epoch 127/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0703 - categorical_accuracy: 0.2917
# Epoch 128/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0491 - categorical_accuracy: 0.4722
# Epoch 129/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0342 - categorical_accuracy: 0.5139
# Epoch 130/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0012 - categorical_accuracy: 0.4444
# Epoch 131/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0393 - categorical_accuracy: 0.4583
# Epoch 132/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0027 - categorical_accuracy: 0.4722
# Epoch 133/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9873 - categorical_accuracy: 0.5556
# Epoch 134/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0299 - categorical_accuracy: 0.4722
# Epoch 135/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.9485 - categorical_accuracy: 0.6250
# Epoch 136/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0128 - categorical_accuracy: 0.4583
# Epoch 137/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9762 - categorical_accuracy: 0.4444
# Epoch 138/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9925 - categorical_accuracy: 0.5000
# Epoch 139/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9892 - categorical_accuracy: 0.6111
# Epoch 140/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.0087 - categorical_accuracy: 0.4028
# Epoch 141/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0213 - categorical_accuracy: 0.4444
# Epoch 142/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.9804 - categorical_accuracy: 0.4583
# Epoch 143/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9770 - categorical_accuracy: 0.4306
# Epoch 144/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.9478 - categorical_accuracy: 0.5556
# Epoch 145/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9601 - categorical_accuracy: 0.5417
# Epoch 146/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9253 - categorical_accuracy: 0.5417
# Epoch 147/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9699 - categorical_accuracy: 0.5833
# Epoch 148/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.9865 - categorical_accuracy: 0.4167
# Epoch 149/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0850 - categorical_accuracy: 0.5833
# Epoch 150/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0757 - categorical_accuracy: 0.3889
# Epoch 151/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9346 - categorical_accuracy: 0.5556
# Epoch 152/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.9413 - categorical_accuracy: 0.5833
# Epoch 153/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.8584 - categorical_accuracy: 0.6944
# Epoch 154/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8966 - categorical_accuracy: 0.6667
# Epoch 155/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8755 - categorical_accuracy: 0.5694
# Epoch 156/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.8232 - categorical_accuracy: 0.6528
# Epoch 157/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8933 - categorical_accuracy: 0.4861
# Epoch 158/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9228 - categorical_accuracy: 0.5000
# Epoch 159/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8660 - categorical_accuracy: 0.5000
# Epoch 160/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9580 - categorical_accuracy: 0.5417
# Epoch 161/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8339 - categorical_accuracy: 0.5139
# Epoch 162/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.8316 - categorical_accuracy: 0.5833
# Epoch 163/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9747 - categorical_accuracy: 0.4444
# Epoch 164/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0035 - categorical_accuracy: 0.5139
# Epoch 165/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9234 - categorical_accuracy: 0.6111
# Epoch 166/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.7939 - categorical_accuracy: 0.6667
# Epoch 167/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.8472 - categorical_accuracy: 0.5833
# Epoch 168/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8266 - categorical_accuracy: 0.5278
# Epoch 169/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8932 - categorical_accuracy: 0.5833
# Epoch 170/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9309 - categorical_accuracy: 0.5139
# Epoch 171/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.8177 - categorical_accuracy: 0.5972
# Epoch 172/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8034 - categorical_accuracy: 0.5278
# Epoch 173/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.7238 - categorical_accuracy: 0.7500
# Epoch 174/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.7008 - categorical_accuracy: 0.6111
# Epoch 175/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6709 - categorical_accuracy: 0.7778
# Epoch 176/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.6582 - categorical_accuracy: 0.7083
# Epoch 177/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.6326 - categorical_accuracy: 0.8194
# Epoch 178/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7046 - categorical_accuracy: 0.5833
# Epoch 179/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6629 - categorical_accuracy: 0.7222
# Epoch 180/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7193 - categorical_accuracy: 0.6944
# Epoch 181/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6452 - categorical_accuracy: 0.7500
# Epoch 182/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6795 - categorical_accuracy: 0.7083
# Epoch 183/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.6961 - categorical_accuracy: 0.6528
# Epoch 184/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6414 - categorical_accuracy: 0.6389
# Epoch 185/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7069 - categorical_accuracy: 0.6389
# Epoch 186/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6204 - categorical_accuracy: 0.7083
# Epoch 187/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.5900 - categorical_accuracy: 0.7778
# Epoch 188/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5940 - categorical_accuracy: 0.7361
# Epoch 189/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.5701 - categorical_accuracy: 0.7361
# Epoch 190/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5954 - categorical_accuracy: 0.7083
# Epoch 191/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.6819 - categorical_accuracy: 0.6667
# Epoch 192/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9262 - categorical_accuracy: 0.5972
# Epoch 193/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.5975 - categorical_accuracy: 0.7778
# Epoch 194/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.6704 - categorical_accuracy: 0.6389
# Epoch 195/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.8406 - categorical_accuracy: 0.7083
# Epoch 196/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6023 - categorical_accuracy: 0.6667
# Epoch 197/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.6977 - categorical_accuracy: 0.7083
# Epoch 198/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7598 - categorical_accuracy: 0.4861
# Epoch 199/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.5542 - categorical_accuracy: 0.7500
# Epoch 200/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6165 - categorical_accuracy: 0.7083
# Epoch 201/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6555 - categorical_accuracy: 0.7083
# Epoch 202/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5557 - categorical_accuracy: 0.7361
# Epoch 203/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5811 - categorical_accuracy: 0.7361
# Epoch 204/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6244 - categorical_accuracy: 0.6944
# Epoch 205/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.5806 - categorical_accuracy: 0.7500
# Epoch 206/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.5751 - categorical_accuracy: 0.7500
# Epoch 207/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4831 - categorical_accuracy: 0.7917
# Epoch 208/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4763 - categorical_accuracy: 0.8889
# Epoch 209/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4578 - categorical_accuracy: 0.8611
# Epoch 210/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5788 - categorical_accuracy: 0.6944
# Epoch 211/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6735 - categorical_accuracy: 0.6667
# Epoch 212/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.3733 - categorical_accuracy: 0.5278
# Epoch 213/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.2705 - categorical_accuracy: 0.5417
# Epoch 214/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.3394 - categorical_accuracy: 0.4028
# Epoch 215/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8959 - categorical_accuracy: 0.5694
# Epoch 216/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9742 - categorical_accuracy: 0.5972
# Epoch 217/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5734 - categorical_accuracy: 0.8056
# Epoch 218/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.7763 - categorical_accuracy: 0.7083
# Epoch 219/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7417 - categorical_accuracy: 0.5833
# Epoch 220/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.6121 - categorical_accuracy: 0.7639
# Epoch 221/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.6764 - categorical_accuracy: 0.6389
# Epoch 222/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5851 - categorical_accuracy: 0.7639
# Epoch 223/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7471 - categorical_accuracy: 0.5694
# Epoch 224/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.8599 - categorical_accuracy: 0.5694
# Epoch 225/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8830 - categorical_accuracy: 0.5417
# Epoch 226/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.5910 - categorical_accuracy: 0.7639
# Epoch 227/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7126 - categorical_accuracy: 0.6111
# Epoch 228/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.5106 - categorical_accuracy: 0.8472
# Epoch 229/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5311 - categorical_accuracy: 0.7500
# Epoch 230/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4586 - categorical_accuracy: 0.8056
# Epoch 231/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4487 - categorical_accuracy: 0.8750
# Epoch 232/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4566 - categorical_accuracy: 0.8472
# Epoch 233/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.5090 - categorical_accuracy: 0.7500
# Epoch 234/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4547 - categorical_accuracy: 0.8056
# Epoch 235/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4890 - categorical_accuracy: 0.7500
# Epoch 236/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.4142 - categorical_accuracy: 0.8611
# Epoch 237/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4712 - categorical_accuracy: 0.7639
# Epoch 238/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4941 - categorical_accuracy: 0.8472
# Epoch 239/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3882 - categorical_accuracy: 0.8333
# Epoch 240/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3758 - categorical_accuracy: 0.7778
# Epoch 241/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.5513 - categorical_accuracy: 0.7778
# Epoch 242/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4021 - categorical_accuracy: 0.8472
# Epoch 243/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3405 - categorical_accuracy: 0.8611
# Epoch 244/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3170 - categorical_accuracy: 0.8889
# Epoch 245/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3110 - categorical_accuracy: 0.8750
# Epoch 246/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3317 - categorical_accuracy: 0.9028
# Epoch 247/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.3703 - categorical_accuracy: 0.8194
# Epoch 248/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3116 - categorical_accuracy: 0.8889
# Epoch 249/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4293 - categorical_accuracy: 0.7917
# Epoch 250/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.4369 - categorical_accuracy: 0.8194
# Epoch 251/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3931 - categorical_accuracy: 0.7778
# Epoch 252/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3538 - categorical_accuracy: 0.7917
# Epoch 253/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.3520 - categorical_accuracy: 0.8889
# Epoch 254/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.2629 - categorical_accuracy: 0.9028
# Epoch 255/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3723 - categorical_accuracy: 0.7778
# Epoch 256/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.3616 - categorical_accuracy: 0.8750
# Epoch 257/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3814 - categorical_accuracy: 0.8056
# Epoch 258/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4719 - categorical_accuracy: 0.8472
# Epoch 259/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.7322 - categorical_accuracy: 0.7361
# Epoch 260/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.3014 - categorical_accuracy: 0.5139
# Epoch 261/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9772 - categorical_accuracy: 0.5972
# Epoch 262/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.8262 - categorical_accuracy: 0.5278
# Epoch 263/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5825 - categorical_accuracy: 0.7778
# Epoch 264/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4060 - categorical_accuracy: 0.8472
# Epoch 265/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.4155 - categorical_accuracy: 0.8056
# Epoch 266/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.3942 - categorical_accuracy: 0.8472
# Epoch 267/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4575 - categorical_accuracy: 0.6944
# Epoch 268/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3944 - categorical_accuracy: 0.8889
# Epoch 269/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2978 - categorical_accuracy: 0.9167
# Epoch 270/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3262 - categorical_accuracy: 0.8472
# Epoch 271/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3016 - categorical_accuracy: 0.9028
# Epoch 272/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.2648 - categorical_accuracy: 0.9167
# Epoch 273/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3091 - categorical_accuracy: 0.9028
# Epoch 274/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2454 - categorical_accuracy: 0.9306
# Epoch 275/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2811 - categorical_accuracy: 0.8889
# Epoch 276/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2361 - categorical_accuracy: 0.9028
# Epoch 277/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2116 - categorical_accuracy: 0.9167
# Epoch 278/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2062 - categorical_accuracy: 0.9306
# Epoch 279/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2128 - categorical_accuracy: 0.9167
# Epoch 280/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.2104 - categorical_accuracy: 0.9028
# Epoch 281/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2010 - categorical_accuracy: 0.9028
# Epoch 282/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2089 - categorical_accuracy: 0.9028
# Epoch 283/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1865 - categorical_accuracy: 0.9167
# Epoch 284/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2042 - categorical_accuracy: 0.9167
# Epoch 285/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1849 - categorical_accuracy: 0.9306
# Epoch 286/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2009 - categorical_accuracy: 0.9306
# Epoch 287/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1803 - categorical_accuracy: 0.9444
# Epoch 288/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.2211 - categorical_accuracy: 0.8889
# Epoch 289/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2025 - categorical_accuracy: 0.9028
# Epoch 290/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2316 - categorical_accuracy: 0.8889
# Epoch 291/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1647 - categorical_accuracy: 0.9583
# Epoch 292/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1537 - categorical_accuracy: 0.9444
# Epoch 293/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.5636 - categorical_accuracy: 0.7778
# Epoch 294/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3558 - categorical_accuracy: 0.8333
# Epoch 295/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3877 - categorical_accuracy: 0.8333
# Epoch 296/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2462 - categorical_accuracy: 0.9167
# Epoch 297/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2442 - categorical_accuracy: 0.9167
# Epoch 298/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.2650 - categorical_accuracy: 0.8611
# Epoch 299/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2187 - categorical_accuracy: 0.9167
# Epoch 300/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2150 - categorical_accuracy: 0.9306
# Epoch 301/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.2075 - categorical_accuracy: 0.9306
# Epoch 302/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2049 - categorical_accuracy: 0.9028
# Epoch 303/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1701 - categorical_accuracy: 0.9444
# Epoch 304/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1905 - categorical_accuracy: 0.9167
# Epoch 305/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.2297 - categorical_accuracy: 0.8889
# Epoch 306/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2351 - categorical_accuracy: 0.8611
# Epoch 307/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2206 - categorical_accuracy: 0.9028
# Epoch 308/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2747 - categorical_accuracy: 0.9167
# Epoch 309/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2923 - categorical_accuracy: 0.8333
# Epoch 310/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4914 - categorical_accuracy: 0.8056
# Epoch 311/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.4047 - categorical_accuracy: 0.4306
# Epoch 312/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.6318 - categorical_accuracy: 0.5694
# Epoch 313/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.9384 - categorical_accuracy: 0.3611
# Epoch 314/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.7987 - categorical_accuracy: 0.5139
# Epoch 315/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4021 - categorical_accuracy: 0.4306
# Epoch 316/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.2594 - categorical_accuracy: 0.3750
# Epoch 317/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8250 - categorical_accuracy: 0.5417
# Epoch 318/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.8662 - categorical_accuracy: 0.6944
# Epoch 319/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.8183 - categorical_accuracy: 0.5417
# Epoch 320/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6871 - categorical_accuracy: 0.7083
# Epoch 321/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6356 - categorical_accuracy: 0.6806
# Epoch 322/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.6927 - categorical_accuracy: 0.5972
# Epoch 323/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5847 - categorical_accuracy: 0.6806
# Epoch 324/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5138 - categorical_accuracy: 0.8056
# Epoch 325/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5494 - categorical_accuracy: 0.6944
# Epoch 326/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.5635 - categorical_accuracy: 0.7083
# Epoch 327/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4889 - categorical_accuracy: 0.8056
# Epoch 328/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.6088 - categorical_accuracy: 0.6944
# Epoch 329/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4305 - categorical_accuracy: 0.4167
# Epoch 330/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 1.5744 - categorical_accuracy: 0.4167
# Epoch 331/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7180 - categorical_accuracy: 0.6250
# Epoch 332/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9715 - categorical_accuracy: 0.5278
# Epoch 333/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8736 - categorical_accuracy: 0.5694
# Epoch 334/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5947 - categorical_accuracy: 0.7639
# Epoch 335/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.8347 - categorical_accuracy: 0.5139
# Epoch 336/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.6543 - categorical_accuracy: 0.6806
# Epoch 337/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6098 - categorical_accuracy: 0.7222
# Epoch 338/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.6392 - categorical_accuracy: 0.5972
# Epoch 339/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.5430 - categorical_accuracy: 0.8056
# Epoch 340/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5756 - categorical_accuracy: 0.7222
# Epoch 341/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5011 - categorical_accuracy: 0.7500
# Epoch 342/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.4916 - categorical_accuracy: 0.7917
# Epoch 343/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4691 - categorical_accuracy: 0.8194
# Epoch 344/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4873 - categorical_accuracy: 0.7778
# Epoch 345/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4580 - categorical_accuracy: 0.7083
# Epoch 346/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.4241 - categorical_accuracy: 0.8194
# Epoch 347/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4237 - categorical_accuracy: 0.7917
# Epoch 348/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4124 - categorical_accuracy: 0.8333
# Epoch 349/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3976 - categorical_accuracy: 0.8611
# Epoch 350/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4045 - categorical_accuracy: 0.7500
# Epoch 351/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3997 - categorical_accuracy: 0.8333
# Epoch 352/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.4552 - categorical_accuracy: 0.7639
# Epoch 353/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3813 - categorical_accuracy: 0.8333
# Epoch 354/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4436 - categorical_accuracy: 0.7778
# Epoch 355/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4391 - categorical_accuracy: 0.8194
# Epoch 356/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4277 - categorical_accuracy: 0.7778
# Epoch 357/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3910 - categorical_accuracy: 0.8194
# Epoch 358/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.5058 - categorical_accuracy: 0.7639
# Epoch 359/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4192 - categorical_accuracy: 0.7778
# Epoch 360/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3597 - categorical_accuracy: 0.8750
# Epoch 361/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3715 - categorical_accuracy: 0.8472
# Epoch 362/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3887 - categorical_accuracy: 0.8056
# Epoch 363/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3672 - categorical_accuracy: 0.7778
# Epoch 364/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3572 - categorical_accuracy: 0.8611
# Epoch 365/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4191 - categorical_accuracy: 0.8056
# Epoch 366/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4114 - categorical_accuracy: 0.7639
# Epoch 367/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3671 - categorical_accuracy: 0.8056
# Epoch 368/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.3531 - categorical_accuracy: 0.8611
# Epoch 369/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3863 - categorical_accuracy: 0.7639
# Epoch 370/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4251 - categorical_accuracy: 0.7778
# Epoch 371/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4162 - categorical_accuracy: 0.7639
# Epoch 372/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3634 - categorical_accuracy: 0.8056
# Epoch 373/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.3406 - categorical_accuracy: 0.8472
# Epoch 374/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.3412 - categorical_accuracy: 0.8611
# Epoch 375/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3471 - categorical_accuracy: 0.8333
# Epoch 376/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3293 - categorical_accuracy: 0.8472
# Epoch 377/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3229 - categorical_accuracy: 0.8472
# Epoch 378/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3252 - categorical_accuracy: 0.8472
# Epoch 379/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3342 - categorical_accuracy: 0.8056
# Epoch 380/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.3400 - categorical_accuracy: 0.8333
# Epoch 381/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3449 - categorical_accuracy: 0.8611
# Epoch 382/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3295 - categorical_accuracy: 0.8472
# Epoch 383/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3309 - categorical_accuracy: 0.8194
# Epoch 384/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3074 - categorical_accuracy: 0.8472
# Epoch 385/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.3379 - categorical_accuracy: 0.8056
# Epoch 386/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3286 - categorical_accuracy: 0.8056
# Epoch 387/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2983 - categorical_accuracy: 0.8611
# Epoch 388/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3092 - categorical_accuracy: 0.8611
# Epoch 389/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3106 - categorical_accuracy: 0.8194
# Epoch 390/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2991 - categorical_accuracy: 0.8472
# Epoch 391/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3467 - categorical_accuracy: 0.8194
# Epoch 392/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4598 - categorical_accuracy: 0.7639
# Epoch 393/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3440 - categorical_accuracy: 0.8472
# Epoch 394/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3602 - categorical_accuracy: 0.8333
# Epoch 395/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.3259 - categorical_accuracy: 0.8472
# Epoch 396/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3015 - categorical_accuracy: 0.8194
# Epoch 397/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3496 - categorical_accuracy: 0.8056
# Epoch 398/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3211 - categorical_accuracy: 0.8750
# Epoch 399/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2947 - categorical_accuracy: 0.8611
# Epoch 400/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2972 - categorical_accuracy: 0.9028
# Epoch 401/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.2896 - categorical_accuracy: 0.8750
# Epoch 402/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2716 - categorical_accuracy: 0.8472
# Epoch 403/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2772 - categorical_accuracy: 0.8611
# Epoch 404/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2805 - categorical_accuracy: 0.8611
# Epoch 405/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2584 - categorical_accuracy: 0.8472
# Epoch 406/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2809 - categorical_accuracy: 0.8472
# Epoch 407/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2722 - categorical_accuracy: 0.8889
# Epoch 408/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2756 - categorical_accuracy: 0.8750
# Epoch 409/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.2841 - categorical_accuracy: 0.8472
# Epoch 410/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3098 - categorical_accuracy: 0.8750
# Epoch 411/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.3905 - categorical_accuracy: 0.8194
# Epoch 412/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3887 - categorical_accuracy: 0.7917
# Epoch 413/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3663 - categorical_accuracy: 0.8333
# Epoch 414/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3937 - categorical_accuracy: 0.8472
# Epoch 415/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.8900 - categorical_accuracy: 0.4861
# Epoch 416/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.7404 - categorical_accuracy: 0.6806
# Epoch 417/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9518 - categorical_accuracy: 0.7222
# Epoch 418/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1676 - categorical_accuracy: 0.5278
# Epoch 419/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.6911 - categorical_accuracy: 0.6389
# Epoch 420/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6144 - categorical_accuracy: 0.6806
# Epoch 421/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6908 - categorical_accuracy: 0.5694
# Epoch 422/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5897 - categorical_accuracy: 0.7500
# Epoch 423/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5131 - categorical_accuracy: 0.7500
# Epoch 424/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.4206 - categorical_accuracy: 0.8611
# Epoch 425/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3995 - categorical_accuracy: 0.8889
# Epoch 426/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.4173e-06 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.4057e-06 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.3875e-06 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 3.3858e-06 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 3.3676e-06 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.3560e-06 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 3.3494e-06 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.3262e-06 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 3.3097e-06 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.3064e-06 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 3.2915e-06 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.2832e-06 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 3.2733e-06 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.2666e-06 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.2617e-06 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.2484e-06 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 3.2517e-06 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 3.2401e-06 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 3.2236e-06 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 3.2120e-06 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 3.1971e-06 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.2037e-06 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 3.1938e-06 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.1839e-06 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.1805e-06 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 3.1756e-06 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 3.1656e-06 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 3.1408e-06 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.1325e-06 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 3.1325e-06 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.1176e-06 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.0961e-06 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 3.0928e-06 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 3.0795e-06 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 3.0680e-06 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 3.0613e-06 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.0514e-06 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.0497e-06 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 3.0448e-06 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 3.0348e-06 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.0233e-06 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.0282e-06 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 3.0133e-06 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.0183e-06 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 3.0150e-06 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 3.0133e-06 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.0067e-06 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.9918e-06 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.9736e-06 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.9587e-06 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.9405e-06 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.9355e-06 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.9223e-06 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 2.9173e-06 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 2.9123e-06 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 2.9024e-06 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.8925e-06 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 2.8776e-06 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.8792e-06 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 2.8627e-06 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.8593e-06 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.8494e-06 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 2.8560e-06 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.8461e-06 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 55ms/step - loss: 2.8411e-06 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 2.8179e-06 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 2.8030e-06 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 2.8014e-06 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 2.7881e-06 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 2.7848e-06 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.7716e-06 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.7683e-06 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 2.7617e-06 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.7517e-06 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.7517e-06 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 2.7468e-06 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 2.7468e-06 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.7501e-06 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 2.7434e-06 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.7252e-06 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.7004e-06 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.6905e-06 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.6805e-06 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.6673e-06 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.6673e-06 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.6607e-06 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.6574e-06 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.6458e-06 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 2.6391e-06 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.6325e-06 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.6176e-06 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.6060e-06 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 2.5862e-06 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 2.5845e-06 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.5828e-06 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.5746e-06 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.5679e-06 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.5646e-06 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.5795e-06 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.5580e-06 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.5348e-06 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.5216e-06 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.5083e-06 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.4984e-06 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.5100e-06 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.5232e-06 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 2.5034e-06 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.4968e-06 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 2.4901e-06 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.4752e-06 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.4653e-06 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.4603e-06 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.4520e-06 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.4438e-06 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.4338e-06 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.4289e-06 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.4289e-06 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.4173e-06 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 2.4107e-06 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.4040e-06 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 2.3958e-06 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.3875e-06 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.3742e-06 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.3626e-06 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.3494e-06 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 2.3527e-06 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.3411e-06 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 2.3378e-06 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 2.3246e-06 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.3130e-06 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.3097e-06 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 2.2931e-06 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.2981e-06 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.2898e-06 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 2.2915e-06 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 483ms/step

# %%
actions[np.argmax(res[1])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'hello'

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# ## Evaluation the model

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_train)
# Out:
# 3/3 [==============================] - 0s 21ms/step

# %%
ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[46,  0],
#         [ 0, 26]],
#
#        [[52,  0],
#         [ 0, 20]],
#
#        [[46,  0],
#         [ 0, 26]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# ## Testing the model in real time

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 126ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 85ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 79ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 87ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 103ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 97ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 77ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 95ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# i_love_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(9, 9))
plt.imshow(prob_viz(res, actions, image, colors))
